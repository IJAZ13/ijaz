# %%
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['E001', 'M', 34, 123, 'Normal', 350],
        ['E002', 'F', 40, 114, 'Overweight', 450],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]

# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['EMPID', 'Gender','Age', 'Sales','BMI', 'Income'] )

# create histogram for numeric data
df.hist()
# show plot
plt.show()

# %%
from turtle import color


data = [['E001', 'M', 34, 123, 'Normal', 50],
        ['E002', 'F', 40, 114, 'Overweight', 150],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]
df = pd.DataFrame(data, columns = ['EMPID', 'Gender','Age', 'Sales','BMI', 'Income'] )

df.plot.box()
plt.show()
plt.boxplot(df['Age'])
plt.title(' plot for sales persons',color='red')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
  
# create 2D array of table given above
data = [['E001', 'M', 34, 123, 'Normal', 50],
        ['E002', 'F', 40, 114, 'Overweight', 150],
        ['E003', 'F', 37, 135, 'Obesity', 169],
        ['E004', 'M', 30, 139, 'Underweight', 189],
        ['E005', 'F', 44, 117, 'Underweight', 183],
        ['E006', 'M', 36, 121, 'Normal', 80],
        ['E007', 'M', 32, 133, 'Obesity', 166],
        ['E008', 'F', 26, 140, 'Normal', 120],
        ['E009', 'M', 32, 133, 'Normal', 75],
        ['E010', 'M', 36, 133, 'Underweight', 40] ]

# dataframe created with
# the above data array
df = pd.DataFrame(data, columns = ['EMPID', 'Gender','Age', 'Sales','BMI', 'Income'] )
df.plot.bar()
plt.show()
plt.bar(df['Age'], df['Income'])
plt.show()

# %%
print("Pie Chart of Age")
plt.pie(df['Age'], labels = {"A", "B", "C","D", "E", "F", "G"}, autopct='% 1.1f %%', shadow = True)
plt.show()

print("Pie Chart of Income")
plt.pie(df['Income'], labels = {"A", "B", "C", "D", "E", "F","G"},autopct ='% 1.1f %%', shadow = True)
plt.show()

print("Pie Chart of Sales")
plt.pie(df['Sales'], labels = {"A", "B", "C", "D", "E", "F", "G"},autopct ='% 1.1f %%', shadow = True)
plt.show()
# Out:
# Pie Chart of Age
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# f:\ijaz\pandas.ipynb Cell 4 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/f%3A/ijaz/pandas.ipynb#ch0000003?line=0'>1</a> print("Pie Chart of Age")
# ----> <a href='vscode-notebook-cell:/f%3A/ijaz/pandas.ipynb#ch0000003?line=1'>2</a> plt.pie(df['Age'], labels = {"A", "B", "C","D", "E", "F", "G"}, autopct='% 1.1f %%', shadow = True)
#       <a href='vscode-notebook-cell:/f%3A/ijaz/pandas.ipynb#ch0000003?line=2'>3</a> plt.show()
#       <a href='vscode-notebook-cell:/f%3A/ijaz/pandas.ipynb#ch0000003?line=4'>5</a> print("Pie Chart of Income")
#
# File c:\Users\User5\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\pyplot.py:2754, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2747 @_copy_docstring_and_deprecators(Axes.pie)
#    2748 def pie(
#    2749         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2752         textprops=None, center=(0, 0), frame=False,
#    2753         rotatelabels=False, *, normalize=True, data=None):
# -> 2754     return gca().pie(
#    2755         x, explode=explode, labels=labels, colors=colors,
#    2756         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#    2757         labeldistance=labeldistance, startangle=startangle,
#    2758         radius=radius, counterclock=counterclock,
#    2759         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    2760         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
#    2761         **({"data": data} if data is not None else {}))
#
# File c:\Users\User5\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File c:\Users\User5\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:3064, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3062     explode = [0] * len(x)
#    3063 if len(x) != len(labels):
# -> 3064     raise ValueError("'label' must be of length 'x'")
#    3065 if len(x) != len(explode):
#    3066     raise ValueError("'explode' must be of length 'x'")
#
# ValueError: 'label' must be of length 'x'
